# %%
import os
import pandas as pd

rpath = 'cookie_cats.csv'

path = os.getcwd() # get current work directory
df = pd.read_csv(os.path.join(path,rpath))

# %%
test1 = df.isnull()#.values #.any()
print(test1)

# df.isnull() is still kind of dataframe
# because isnull() is just function to find null in df
# but df.isnull().values removes the all information of df
# any finds any fault based on the entire array
# Out:
#        userid  version  sum_gamerounds  retention_1  retention_7
# 0       False    False           False        False        False
# 1       False    False           False        False        False
# 2       False    False           False        False        False
# 3       False    False           False        False        False
# 4       False    False           False        False        False
# ...       ...      ...             ...          ...          ...
# 90184   False    False           False        False        False
# 90185   False    False           False        False        False
# 90186   False    False           False        False        False
# 90187   False    False           False        False        False
# 90188   False    False           False        False        False
#
# [90189 rows x 5 columns]

# %%
test2 = df.isnull().any()
print(test2)
# Out:
# userid            False
# version           False
# sum_gamerounds    False
# retention_1       False
# retention_7       False
# dtype: bool

# %%
df.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3        False        False
# 1     337  gate_30              38         True        False
# 2     377  gate_40             165         True        False
# 3     483  gate_40               1        False        False
# 4     488  gate_40             179         True         True

# %%
(6676+6506)/sum([38023, 6676, 38983,6506])
# Out:
# 0.14616135184281723
